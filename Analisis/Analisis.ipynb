# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('/home/enzo/Proyectos/Autos_usados/Data/autos_usados.csv')

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://auto.mercadolibre.com.ar/MLA-113169210...
# 1  https://auto.mercadolibre.com.ar/MLA-113164086...
# 2  https://auto.mercadolibre.com.ar/MLA-112881951...
# 3  https://auto.mercadolibre.com.ar/MLA-112696239...
# 4  https://auto.mercadolibre.com.ar/MLA-113378675...
#
#                                               title     price currency_symbol  \
# 0             BMW Serie 1 1.6 120i Sport Line 177cv     28500             U$S
# 1   BMW Serie 4 2.0 430i Gran Coupe Sportline 252cv     45000             U$S
# 2      Toyota Land Cruiser 4.5 200 V8 D4-d 235cv At     41900             U$S
# 3  Audi A5 Sportback 2.0 Tfsi Stronic Quattro 230cv     46900             U$S
# 4                  Volkswagen Amarok 3.0 V6 Extreme  12200000               $
#
#         Marca        Modelo   Año          Color Tipo de combustible  Puertas  \
# 0         BMW       Serie 1  2016         Blanco               Nafta        5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1900 entries, 0 to 1899
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   url                  1900 non-null   object
#  1   title                1900 non-null   object
#  2   price                1900 non-null   int64
#  3   currency_symbol      1900 non-null   object
#  4   Marca                1900 non-null   object
#  5   Modelo               1900 non-null   object
#  6   Año                  1900 non-null   int64
#  7   Color                1833 non-null   object
#  8   Tipo de combustible  1900 non-null   object
#  9   Puertas              1900 non-null   int64
#  10  Transmisión          1900 non-null   object
#  11  Motor                1899 non-null   object
#  12  Tipo de carrocería   1898 non-null   object
#  13  Kilómetros           1900 non-null   object
# dtypes: int64(3), object(11)
# memory usage: 207.9+ KB

# %%
df2 = pd.read_csv('/home/enzo/Proyectos/Autos_usados/Data/autos_usados_v2.csv')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1898 entries, 0 to 1897
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   url              1898 non-null   object
#  1   title            1898 non-null   object
#  2   price            1898 non-null   int64
#  3   currency_symbol  1898 non-null   object
#  4   marca            1898 non-null   object
#  5   modelo           1898 non-null   object
#  6   year             1898 non-null   int64
#  7   color            1898 non-null   object
#  8   combustible      1898 non-null   object
#  9   puertas          1898 non-null   int64
#  10  transmision      1898 non-null   object
#  11  motor            1898 non-null   float64
#  12  carroceria       1898 non-null   object
#  13  km               1898 non-null   int64
#  14  price_in_pesos   1898 non-null   int64
# dtypes: float64(1), int64(5), object(9)
# memory usage: 222.5+ KB

# %%
df2.head()
# Out:
#                                                  url  \
# 0  https://auto.mercadolibre.com.ar/mla-113169210...
# 1  https://auto.mercadolibre.com.ar/mla-113164086...
# 2  https://auto.mercadolibre.com.ar/mla-112881951...
# 3  https://auto.mercadolibre.com.ar/mla-112696239...
# 4  https://auto.mercadolibre.com.ar/mla-113378675...
#
#                                               title     price currency_symbol  \
# 0             bmw serie 1 1.6 120i sport line 177cv     28500             u$s
# 1   bmw serie 4 2.0 430i gran coupe sportline 252cv     45000             u$s
# 2      toyota land cruiser 4.5 200 v8 d4-d 235cv at     41900             u$s
# 3  audi a5 sportback 2.0 tfsi stronic quattro 230cv     46900             u$s
# 4                  volkswagen amarok 3.0 v6 extreme  12200000               $
#
#         marca        modelo  year          color combustible  puertas  \
# 0         bmw       serie 1  2016         blanco       nafta        5
# ...

# %%
df3 = pd.read_csv('/home/enzo/Proyectos/Autos_usados/Data/autos_usados_v3_modelo.csv')

# %%
df3.head()
# Out:
#         marca  year          color combustible  puertas transmision  motor  \
# 0         bmw  2016         blanco       nafta        5      manual    1.6
# 1         bmw  2017          negro       nafta        2  automática    2.0
# 2      toyota  2010       plateado      diésel        5  automática    4.5
# 3        audi  2017  azul petróleo       nafta        3  automática    2.0
# 4  volkswagen  2021           gris      diésel        4  automática    3.0
#
#   carroceria      km  price_in_pesos
# 0  hatchback   99800         5700000
# 1      coupé   39200         9000000
# 2        suv  240000         8380000
# 3  hatchback   54000         9380000
# 4    pick-up   29000        12200000

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1898 entries, 0 to 1897
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   marca           1898 non-null   object
#  1   year            1898 non-null   int64
#  2   color           1898 non-null   object
#  3   combustible     1898 non-null   object
#  4   puertas         1898 non-null   int64
#  5   transmision     1898 non-null   object
#  6   motor           1898 non-null   float64
#  7   carroceria      1898 non-null   object
#  8   km              1898 non-null   int64
#  9   price_in_pesos  1898 non-null   int64
# dtypes: float64(1), int64(4), object(5)
# memory usage: 148.4+ KB

# %%
df3
# Out:
#            marca  year          color combustible  puertas transmision  motor  \
# 0            bmw  2016         blanco       nafta        5      manual    1.6
# 1            bmw  2017          negro       nafta        2  automática    2.0
# 2         toyota  2010       plateado      diésel        5  automática    4.5
# 3           audi  2017  azul petróleo       nafta        3  automática    2.0
# 4     volkswagen  2021           gris      diésel        4  automática    3.0
# ...          ...   ...            ...         ...      ...         ...    ...
# 1893  volkswagen  2021           gris       nafta        5      manual    1.6
# 1894   chevrolet  2016           gris       nafta        5  automática    1.8
# 1895     peugeot  2016         blanco       nafta        5      manual    1.6
# 1896      toyota  2017         blanco       nafta        4      manual    1.8
# 1897   chevrolet  2015           gris       nafta        4      manual    1.4
#
# ...

# %%
df2.motor.value_counts().keys().sort_values()
# Out:
# Float64Index([1.0, 1.2, 1.3, 1.4, 1.5, 1.6, 1.8, 1.9, 2.0, 2.1, 2.2, 2.3, 2.4,
#               2.5, 2.7, 2.8, 3.0, 3.2, 3.5, 3.6, 3.7, 3.8, 4.2, 4.4, 4.5, 5.0,
#               5.7, 6.2, 6.4, 6.7],
#              dtype='float64')

# %%
fig, axes = plt.subplots(5, 2, figsize=(20,30))
axe = axes.ravel()


for i, col in enumerate(df3.columns.values[:-1]):
    df3.plot(x=col, y='price_in_pesos', kind='scatter', ax=axe[i])


axes[0,0].set_xticklabels(df2.marca.unique(), rotation=90)
axes[1,0].set_xticklabels(df2.color.unique(), rotation=90)
axes[3,0].set_xticks(df2.motor.value_counts().keys().sort_values(), rotation=90)
axes[3,0].set_xticklabels(df2.motor.value_counts().keys().sort_values(),rotation=90)

fig.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_9797/3365084554.py:9: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[0,0].set_xticklabels(df2.marca.unique(), rotation=90)
# /tmp/ipykernel_9797/3365084554.py:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[1,0].set_xticklabels(df2.color.unique(), rotation=90)

# %%
round(df2.groupby(['motor', 'carroceria'])[['price_in_pesos']].mean())
# Out:
#                   price_in_pesos
# motor carroceria
# 1.0   hatchback        3323922.0
#       suv              5806000.0
# 1.2   cabriolet        4580000.0
#       hatchback        1423531.0
#       suv              4302900.0
# ...                          ...
# 5.7   pick-up          8820571.0
# 6.2   cabriolet       17400000.0
#       coupé           13889900.0
# 6.4   suv             21800000.0
# 6.7   pick-up         16766667.0
#
# [100 rows x 1 columns]

# %%
df2.carroceria.value_counts().keys()
# Out:
# Index(['hatchback', 'suv', 'sedán', 'pick-up', 'monovolumen', 'furgón',
#        'coupé', 'rural', 'cabriolet', 'off-road', 'light truck'],
#       dtype='object')

# %%
fig = plt.figure(figsize =(12, 7))
plt.bar(df2.carroceria.value_counts().keys(), df2.carroceria.value_counts().values)
plt.xticks(rotation=90)
plt.title('Tipos de carroceria', fontdict={'fontsize':18})
plt.show()

# %%
top_5_marcas
# Out:
#             price_in_pesos
# marca
# alfa romeo      3080000.00
# audi            9350893.92
# bmw             8768221.41
# chery           2363590.91
# chevrolet       3379858.29

# %%
round(df2.groupby('marca').mean().sort_values(by='price_in_pesos', ascending=False)[['price_in_pesos']],2).head()
# Out:
#                price_in_pesos
# marca
# porsche           40300000.00
# jaguar            13800000.00
# volvo             10665000.00
# ram               10222823.53
# mercedes-benz      9887130.00

# %%
round(df2.groupby('marca').mean().sort_values(by='price_in_pesos', ascending=False)[['price_in_pesos']],2).head().plot.barh(figsize=(14,6))
plt.title('Top 5 marcas por precio', fontdict={'fontsize':18})
plt.show()
